# %% [markdown]
# <a href="https://colab.research.google.com/github/sairamdoddathallipadmanabhachar/7043SCN/blob/main/SaiRamDoddathalliPadmanabhachar_16984381.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello world')
# Out:
# hello world
